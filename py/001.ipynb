# %%
import numpy as np
# import scipy as scp
import matplotlib.pyplot as plt
import pandas as pd
# import sympy as sym
import sklearn as sk
import seaborn as sns

# %%
df = pd.read_csv('diabetes.csv')
# x = df.data
# y = df.target

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df = pd.DataFrame(df)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x = df.drop('Outcome',axis=1)

# %%
y = df['Outcome']

# %%
from sklearn.model_selection import train_test_split
xtrn,xtst,ytrn,ytst=train_test_split(x,y,test_size=0.2)


import tensorflow as tf

from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense


model = keras.Sequential()
model.add(Dense(20, input_dim=8, activation="relu"))
model.add(Dense(18, activation="relu"))
model.add(Dense(15, activation="sigmoid"))
# model.add(Dense(10, activation="relu"))
# model.add(Dense(5, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

# %%
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(xtrn,ytrn, epochs=700)

_, accuracy = model.evaluate(xtst, ytst)
print("Model accuracy: %.2f"% (accuracy*100))

predictions = model.predict(x)
print([round(x[0]) for x in predictions])
# Out:
# Epoch 1/700
# 20/20 [==============================] - 1s 2ms/step - loss: 0.2861 - accuracy: 0.8909
# Epoch 2/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2844 - accuracy: 0.8697
# Epoch 3/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2716 - accuracy: 0.8779
# Epoch 4/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2619 - accuracy: 0.8844
# Epoch 5/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2575 - accuracy: 0.8860
# Epoch 6/700
# 20/20 [==============================] - 0s 7ms/step - loss: 0.2627 - accuracy: 0.8893
# Epoch 7/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2589 - accuracy: 0.8860
# Epoch 8/700
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2621 - accuracy: 0.8893
# Epoch 9/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2695 - accuracy: 0.8779
# Epoch 10/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2695 - accuracy: 0.8844
# Epoch 11/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2630 - accuracy: 0.8827
# Epoch 12/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2768 - accuracy: 0.8860
# Epoch 13/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2656 - accuracy: 0.8909
# Epoch 14/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2646 - accuracy: 0.8746
# Epoch 15/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2645 - accuracy: 0.8762
# Epoch 16/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2760 - accuracy: 0.8795
# Epoch 17/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2697 - accuracy: 0.8779
# Epoch 18/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2879 - accuracy: 0.8746
# Epoch 19/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2941 - accuracy: 0.8697
# Epoch 20/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2752 - accuracy: 0.8779
# Epoch 21/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2676 - accuracy: 0.8779
# Epoch 22/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2646 - accuracy: 0.8876
# Epoch 23/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2598 - accuracy: 0.8811
# Epoch 24/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2535 - accuracy: 0.8909
# Epoch 25/700
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2744 - accuracy: 0.8779
# Epoch 26/700
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2755 - accuracy: 0.8746
# Epoch 27/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2659 - accuracy: 0.8811
# Epoch 28/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2666 - accuracy: 0.8827
# Epoch 29/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2621 - accuracy: 0.8811
# Epoch 30/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2525 - accuracy: 0.8925
# Epoch 31/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2651 - accuracy: 0.8844
# Epoch 32/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2661 - accuracy: 0.8844
# Epoch 33/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2602 - accuracy: 0.8860
# Epoch 34/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2744 - accuracy: 0.8730
# Epoch 35/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2703 - accuracy: 0.8795
# Epoch 36/700
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2539 - accuracy: 0.8909
# Epoch 37/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2602 - accuracy: 0.8909
# Epoch 38/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2562 - accuracy: 0.8909
# Epoch 39/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2505 - accuracy: 0.8925
# Epoch 40/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2612 - accuracy: 0.8925
# Epoch 41/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2649 - accuracy: 0.8844
# Epoch 42/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2620 - accuracy: 0.8876
# Epoch 43/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2653 - accuracy: 0.8795
# Epoch 44/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2685 - accuracy: 0.8860
# Epoch 45/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2623 - accuracy: 0.8860
# Epoch 46/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2705 - accuracy: 0.8811
# Epoch 47/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2959 - accuracy: 0.8681
# Epoch 48/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2633 - accuracy: 0.8925
# Epoch 49/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2620 - accuracy: 0.8893
# Epoch 50/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2650 - accuracy: 0.8876
# Epoch 51/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2528 - accuracy: 0.9007
# Epoch 52/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2514 - accuracy: 0.8941
# Epoch 53/700
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2507 - accuracy: 0.8925: 0s - loss: 0.2211 - accuracy: 0.90
# Epoch 54/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2715 - accuracy: 0.8844
# Epoch 55/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2755 - accuracy: 0.8795
# Epoch 56/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2789 - accuracy: 0.8730
# Epoch 57/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2647 - accuracy: 0.8909
# Epoch 58/700
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2800 - accuracy: 0.8697
# Epoch 59/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2764 - accuracy: 0.8811
# Epoch 60/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2522 - accuracy: 0.8925
# Epoch 61/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2496 - accuracy: 0.8990
# Epoch 62/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2543 - accuracy: 0.8909
# Epoch 63/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2760 - accuracy: 0.8827
# Epoch 64/700
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2584 - accuracy: 0.8860
# Epoch 65/700
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2510 - accuracy: 0.9007
# Epoch 66/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2441 - accuracy: 0.8941
# Epoch 67/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2749 - accuracy: 0.8860
# Epoch 68/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2479 - accuracy: 0.9023
# Epoch 69/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2554 - accuracy: 0.8990
# Epoch 70/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2644 - accuracy: 0.8795
# Epoch 71/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2672 - accuracy: 0.8893
# Epoch 72/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2577 - accuracy: 0.8811
# Epoch 73/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3702 - accuracy: 0.8404
# Epoch 74/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3763 - accuracy: 0.8274
# Epoch 75/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3456 - accuracy: 0.8534
# Epoch 76/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3486 - accuracy: 0.8388
# Epoch 77/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3399 - accuracy: 0.8502
# Epoch 78/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3432 - accuracy: 0.8469
# Epoch 79/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3110 - accuracy: 0.8453
# Epoch 80/700
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2992 - accuracy: 0.8616
# Epoch 81/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2788 - accuracy: 0.8713
# Epoch 82/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2606 - accuracy: 0.8941
# Epoch 83/700
# 20/20 [==============================] - ETA: 0s - loss: 0.2326 - accuracy: 0.90 - 0s 2ms/step - loss: 0.2599 - accuracy: 0.8941
# Epoch 84/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2616 - accuracy: 0.8779
# Epoch 85/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2656 - accuracy: 0.8811
# Epoch 86/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2680 - accuracy: 0.8811
# Epoch 87/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2549 - accuracy: 0.8941
# Epoch 88/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2518 - accuracy: 0.8974
# Epoch 89/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2448 - accuracy: 0.9088
# Epoch 90/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2495 - accuracy: 0.8909
# Epoch 91/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2458 - accuracy: 0.8958
# Epoch 92/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2788 - accuracy: 0.8762
# Epoch 93/700
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2554 - accuracy: 0.8990
# Epoch 94/700
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2510 - accuracy: 0.8974
# Epoch 95/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2658 - accuracy: 0.8844
# Epoch 96/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2599 - accuracy: 0.8827
# Epoch 97/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2539 - accuracy: 0.8844
# Epoch 98/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2554 - accuracy: 0.8893
# Epoch 99/700
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2585 - accuracy: 0.8941
# Epoch 100/700
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2412 - accuracy: 0.9007
# Epoch 101/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2418 - accuracy: 0.8974
# Epoch 102/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2410 - accuracy: 0.9039
# Epoch 103/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2378 - accuracy: 0.9088
# Epoch 104/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2549 - accuracy: 0.8974
# Epoch 105/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2583 - accuracy: 0.8779
# Epoch 106/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2525 - accuracy: 0.8893
# Epoch 107/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2503 - accuracy: 0.8941
# Epoch 108/700
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2498 - accuracy: 0.8958
# Epoch 109/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2467 - accuracy: 0.8990
# Epoch 110/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2471 - accuracy: 0.8990
# Epoch 111/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2457 - accuracy: 0.8974
# Epoch 112/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2448 - accuracy: 0.9039
# Epoch 113/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2545 - accuracy: 0.8860
# Epoch 114/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2595 - accuracy: 0.8860
# Epoch 115/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2405 - accuracy: 0.9055
# Epoch 116/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2406 - accuracy: 0.9072
# Epoch 117/700
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2614 - accuracy: 0.8844
# Epoch 118/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2456 - accuracy: 0.8958
# Epoch 119/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2377 - accuracy: 0.9072
# Epoch 120/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2449 - accuracy: 0.8958
# Epoch 121/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2576 - accuracy: 0.8909
# Epoch 122/700
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2468 - accuracy: 0.8974
# Epoch 123/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2442 - accuracy: 0.8974
# Epoch 124/700
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2365 - accuracy: 0.8974
# Epoch 125/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2479 - accuracy: 0.8958
# Epoch 126/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2537 - accuracy: 0.8990
# Epoch 127/700
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2489 - accuracy: 0.8990
# Epoch 128/700
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2487 - accuracy: 0.8941
# Epoch 129/700
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2654 - accuracy: 0.8811
# Epoch 130/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2536 - accuracy: 0.8876
# Epoch 131/700
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2404 - accuracy: 0.9023
# Epoch 132/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2408 - accuracy: 0.8941
# Epoch 133/700
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2410 - accuracy: 0.8925
# Epoch 134/700
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2569 - accuracy: 0.8779
# Epoch 135/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2653 - accuracy: 0.8762
# Epoch 136/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2675 - accuracy: 0.8844
# Epoch 137/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2397 - accuracy: 0.8958
# Epoch 138/700
# 20/20 [==============================] - ETA: 0s - loss: 0.2450 - accuracy: 0.87 - 0s 2ms/step - loss: 0.2343 - accuracy: 0.9039
# Epoch 139/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2331 - accuracy: 0.9039
# Epoch 140/700
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2397 - accuracy: 0.9039
# Epoch 141/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2365 - accuracy: 0.8990
# Epoch 142/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2449 - accuracy: 0.8844
# Epoch 143/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2459 - accuracy: 0.8990
# Epoch 144/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2656 - accuracy: 0.8844
# Epoch 145/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2510 - accuracy: 0.8893
# Epoch 146/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2399 - accuracy: 0.8974
# Epoch 147/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2435 - accuracy: 0.8958
# Epoch 148/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2514 - accuracy: 0.8974
# Epoch 149/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2437 - accuracy: 0.8941
# Epoch 150/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2451 - accuracy: 0.8909
# Epoch 151/700
# 20/20 [==============================] - 0s 6ms/step - loss: 0.2628 - accuracy: 0.8860
# Epoch 152/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2661 - accuracy: 0.8811
# Epoch 153/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2566 - accuracy: 0.8974
# Epoch 154/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2378 - accuracy: 0.9072
# Epoch 155/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2365 - accuracy: 0.9007
# Epoch 156/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2293 - accuracy: 0.8974
# Epoch 157/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2520 - accuracy: 0.8860
# Epoch 158/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2460 - accuracy: 0.8909
# Epoch 159/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2499 - accuracy: 0.8974
# Epoch 160/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2355 - accuracy: 0.9007
# Epoch 161/700
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2374 - accuracy: 0.9039
# Epoch 162/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2385 - accuracy: 0.8974
# Epoch 163/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2313 - accuracy: 0.9055
# Epoch 164/700
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2352 - accuracy: 0.9055
# Epoch 165/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2363 - accuracy: 0.8958
# Epoch 166/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2359 - accuracy: 0.9007
# Epoch 167/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2280 - accuracy: 0.9137
# Epoch 168/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2321 - accuracy: 0.9007
# Epoch 169/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2354 - accuracy: 0.9088
# Epoch 170/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2308 - accuracy: 0.9055
# Epoch 171/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2332 - accuracy: 0.9072
# Epoch 172/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2422 - accuracy: 0.8958
# Epoch 173/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2506 - accuracy: 0.8909
# Epoch 174/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2756 - accuracy: 0.8795
# Epoch 175/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2749 - accuracy: 0.8795
# Epoch 176/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2417 - accuracy: 0.8876
# Epoch 177/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2392 - accuracy: 0.9007
# Epoch 178/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2336 - accuracy: 0.8990
# Epoch 179/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2368 - accuracy: 0.9007
# Epoch 180/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2475 - accuracy: 0.8990
# Epoch 181/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2440 - accuracy: 0.9007
# Epoch 182/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2475 - accuracy: 0.8974
# Epoch 183/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3837 - accuracy: 0.8371
# Epoch 184/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3288 - accuracy: 0.8502
# Epoch 185/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2712 - accuracy: 0.8713
# Epoch 186/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2415 - accuracy: 0.9007
# Epoch 187/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2394 - accuracy: 0.9039
# Epoch 188/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2336 - accuracy: 0.9007
# Epoch 189/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2234 - accuracy: 0.9007
# Epoch 190/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2384 - accuracy: 0.8925
# Epoch 191/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2279 - accuracy: 0.9007
# Epoch 192/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2243 - accuracy: 0.9072
# Epoch 193/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2537 - accuracy: 0.8827
# Epoch 194/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2502 - accuracy: 0.8876
# Epoch 195/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2385 - accuracy: 0.8941
# Epoch 196/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2370 - accuracy: 0.9088
# Epoch 197/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2309 - accuracy: 0.8990
# Epoch 198/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2291 - accuracy: 0.9039
# Epoch 199/700
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2221 - accuracy: 0.9088
# Epoch 200/700
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2240 - accuracy: 0.9121
# Epoch 201/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2255 - accuracy: 0.9104
# Epoch 202/700
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2310 - accuracy: 0.9072
# Epoch 203/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2188 - accuracy: 0.9088
# Epoch 204/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2333 - accuracy: 0.9023
# Epoch 205/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2278 - accuracy: 0.9104
# Epoch 206/700
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2268 - accuracy: 0.9072
# Epoch 207/700
# 17/20 [========================>.....] - ETA: 0s - loss: 0.2291 - accuracy: 0.9044
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18168/538886492.py in <module>
#       1 model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
#       2
# ----> 3 model.fit(xtrn,ytrn, epochs=700)
#       4
#       5 _, accuracy = model.evaluate(xtst, ytst)
#
# ~\anaconda3\envs\tf_env\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1187               logs = tmp_logs  # No error, now safe to assign to logs.
#    1188               end_step = step + data_handler.step_increment
# -> 1189               callbacks.on_train_batch_end(end_step, logs)
#    1190               if self.stop_training:
#    1191                 break
#
# ~\anaconda3\envs\tf_env\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#     433     """
#     434     if self._should_call_train_batch_hooks:
# --> 435       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     436
#     437   def on_test_batch_begin(self, batch, logs=None):
#
# ~\anaconda3\envs\tf_env\lib\site-packages\keras\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# ~\anaconda3\envs\tf_env\lib\site-packages\keras\callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     313       self._batch_times.append(batch_time)
#     314
# --> 315     self._call_batch_hook_helper(hook_name, batch, logs)
#     316
#     317     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# ~\anaconda3\envs\tf_env\lib\site-packages\keras\callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     351     for callback in self.callbacks:
#     352       hook = getattr(callback, hook_name)
# --> 353       hook(batch, logs)
#     354
#     355     if self._check_timing:
#
# ~\anaconda3\envs\tf_env\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#    1026
#    1027   def on_train_batch_end(self, batch, logs=None):
# -> 1028     self._batch_update_progbar(batch, logs)
#    1029
#    1030   def on_test_batch_end(self, batch, logs=None):
#
# ~\anaconda3\envs\tf_env\lib\site-packages\keras\callbacks.py in _batch_update_progbar(self, batch, logs)
#    1098     if self.verbose == 1:
#    1099       # Only block async when verbose = 1.
# -> 1100       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1101       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1102
#
# ~\anaconda3\envs\tf_env\lib\site-packages\keras\utils\tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     514     return t  # Don't turn ragged or sparse tensors to NumPy.
#     515
# --> 516   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     517
#     518
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~\anaconda3\envs\tf_env\lib\site-packages\keras\utils\tf_utils.py in _to_single_numpy_or_python_type(t)
#     510   def _to_single_numpy_or_python_type(t):
#     511     if isinstance(t, tf.Tensor):
# --> 512       x = t.numpy()
#     513       return x.item() if np.ndim(x) == 0 else x
#     514     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow\python\framework\ops.py in numpy(self)
#    1092     """
#    1093     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1094     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1095     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1096
#
# ~\anaconda3\envs\tf_env\lib\site-packages\tensorflow\python\framework\ops.py in _numpy(self)
#    1058   def _numpy(self):
#    1059     try:
# -> 1060       return self._numpy_internal()
#    1061     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1062       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:
